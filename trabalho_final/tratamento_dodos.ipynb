# %% [markdown]
# # Tratamento de Dados — Autuações de Trânsito DF (2025)
#
# Neste notebook, realizamos a coleta, inspeção e limpeza dos dados de infrações de trânsito do Distrito Federal referentes ao ano de 2025, disponibilizados pelo [Portal de Dados Abertos do DF](https://dados.df.gov.br).
#
# O objetivo é produzir um dataset padronizado e tipado, pronto para análise exploratória.

# %% [markdown]
# ## 1. Coleta e Consolidação dos Dados
#
# Os dados são disponibilizados mensalmente em arquivos CSV separados. Lemos cada mês diretamente da URL e os consolidamos em um único DataFrame.

# %%
import pandas as pd

def readcsv(url):
    return pd.read_csv(url, sep=";", encoding="utf-8")

df_janeiro = readcsv("https://www.dados.df.gov.br/o/dados-abertos/v1.0/datasets/infracoes-transito/resources/4ccce9a2-d46b-47e0-85e7-87f7596e27c6/download")
df_fevereiro = readcsv("https://www.dados.df.gov.br/o/dados-abertos/v1.0/datasets/infracoes-transito/resources/a02bb7e8-e8b8-4450-a4df-bfbc161427ee/download")
df_marco = readcsv("https://www.dados.df.gov.br/o/dados-abertos/v1.0/datasets/infracoes-transito/resources/cc9c9f18-5b99-4f0e-ab5a-267fee9e639c/download")
df_abril = readcsv("https://www.dados.df.gov.br/o/dados-abertos/v1.0/datasets/infracoes-transito/resources/8c093cec-6bdc-441d-bf1b-f3cfed7382d6/download")
df_maio = readcsv("https://www.dados.df.gov.br/o/dados-abertos/v1.0/datasets/infracoes-transito/resources/d87e75ae-4005-4fe3-9ea1-3e70a9c7563d/download")
df_junho = readcsv("https://www.dados.df.gov.br/o/dados-abertos/v1.0/datasets/infracoes-transito/resources/08cdff69-011d-411c-8a44-9cd55c0042a7/download")
df_julho = readcsv("https://www.dados.df.gov.br/o/dados-abertos/v1.0/datasets/infracoes-transito/resources/8382708c-6ca5-4d7c-80e7-a96cefd8ee2d/download")
df_agosto = readcsv("https://www.dados.df.gov.br/o/dados-abertos/v1.0/datasets/infracoes-transito/resources/3ee0c1fa-6609-44bf-81b2-88cef1bdb7c2/download")
df_setembro = readcsv("https://www.dados.df.gov.br/o/dados-abertos/v1.0/datasets/infracoes-transito/resources/077ef49d-1782-459e-be06-2c61edf67eea/download")
df_outubro = readcsv("https://www.dados.df.gov.br/o/dados-abertos/v1.0/datasets/infracoes-transito/resources/8109a912-7e01-4d16-ad1c-2520ee96ae25/download")
df_novembro = readcsv("https://www.dados.df.gov.br/o/dados-abertos/v1.0/datasets/infracoes-transito/resources/f24fe056-9492-4da0-9045-4255fe2e0b55/download")
df_dezembro = readcsv("https://www.dados.df.gov.br/o/dados-abertos/v1.0/datasets/infracoes-transito/resources/d9da46f3-d249-4656-a1a9-99a3f3b8656f/download")

df = pd.concat([df_janeiro, df_fevereiro, df_marco, df_abril, df_maio, df_junho, df_julho, df_agosto, df_setembro, df_outubro, df_novembro, df_dezembro], ignore_index=True)
# Out:
# C:\Users\cauan\AppData\Local\Temp\ipykernel_22256\2060414372.py:4: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(url, sep=";", encoding="utf-8")

# %% [markdown]
# ## 2. Inspeção Inicial
#
# Verificamos a estrutura do DataFrame: número de linhas, colunas, tipos e quais informações estão disponíveis antes de qualquer limpeza.

# %%
# Exibe as primeiras/ultimas linhas e um resumo completo das colunas e tipos
display(df)
display(df.info())
# Out:
#        tipo_infracao                                          descricao  \
# 0             7463-0  Transitar em velocidade superior à máxima perm...
# 1             7455-0  Transitar em velocidade superior à máxima perm...
# 2             7455-0  Transitar em velocidade superior à máxima perm...
# 3             7455-0  Transitar em velocidade superior à máxima perm...
# 4             7455-0  Transitar em velocidade superior à máxima perm...
# ...              ...                                                ...
# 815918        5452-5  Estacionar ao lado ou sobre canteiro central/d...
# 815919        5452-5  Estacionar ao lado ou sobre canteiro central/d...
# 815920        5614-2           Parar na pista de rolamento das rodovias
# 815921        5452-5  Estacionar ao lado ou sobre canteiro central/d...
# 815922        5452-5  Estacionar ao lado ou sobre canteiro central/d...
#
#        tipo_infrator               tipo_veiculo cometimento hora_cometimento  \
# 0           Condutor                  AUTOMOVEL  01/01/2025            00:00
# 1           Condutor  AUTOMOVEL                  01/01/2025            00:00
# 2           Condutor  AUTOMOVEL                  01/01/2025            00:01
# 3           Condutor  AUTOMOVEL                  01/01/2025            00:03
# 4           Condutor                  AUTOMOVEL  01/01/2025            00:05
# ...              ...                        ...         ...              ...
# 815918      Condutor                  Automóvel  31/12/2025            23:36
# 815919      Condutor                  Automóvel  31/12/2025            23:37
# 815920      Condutor                  Automóvel  31/12/2025            23:39
# 815921      Condutor                  Automóvel  31/12/2025            23:47
# 815922      Condutor                  Automóvel  31/12/2025            23:49
#
#                                       auinf_local_rodovia auinf_local_km  \
# 0                          RODOVIA DF-001 (EPCT), KM 64,0            NaN
# 1       DF-459 KM 0,6 SENTIDO CEILANDIA/SAMAMBAIA     ...            NaN
# 2       DF-075 (EPNB) KM 5,7 SENTIDO DF-003 (EPIA)    ...            NaN
# 3       DF-011(EPIG) KM 0,8 SENT. EPTG/EIXO MONUMENTAL...            NaN
# 4                          RODOVIA DF-003 (EPIA) KM 22,6             NaN
# ...                                                   ...            ...
# 815918                                             DF 004             14
# 815919                                             DF 004             14
# 815920                                              DF004             14
# 815921                                             DF 004             14
# 815922                                             DF 004             14
#
#        auinf_local_referencia auinf_local_complemento auinf_local_latitude  \
# 0                         NaN                     NaN                  NaN
# 1                         NaN                     NaN                  NaN
# 2                         NaN                     NaN                  NaN
# 3                         NaN                     NaN                  NaN
# 4                         NaN                     NaN                  NaN
# ...                       ...                     ...                  ...
# 815918    Sentido Decrescente                     NaN                  NaN
# 815919    Sentido Decrescente                     NaN                  NaN
# 815920    Sentido Decrescente                     NaN                  NaN
# 815921    Sentido Decrescente                     NaN                  NaN
# 815922    Sentido Decrescente                     NaN                  NaN
#
#        auinf_local_longitude grav_tipo
# 0                        NaN     Grave
# 1                        NaN     Média
# 2                        NaN     Média
# 3                        NaN     Média
# 4                        NaN     Média
# ...                      ...       ...
# 815918                   NaN     Grave
# 815919                   NaN     Grave
# 815920                   NaN     Grave
# 815921                   NaN     Grave
# 815922                   NaN     Grave
#
# [815923 rows x 13 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 815923 entries, 0 to 815922
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   tipo_infracao            815923 non-null  object
#  1   descricao                815923 non-null  object
#  2   tipo_infrator            815923 non-null  object
#  3   tipo_veiculo             815923 non-null  object
#  4   cometimento              815923 non-null  object
#  5   hora_cometimento         815923 non-null  object
#  6   auinf_local_rodovia      813936 non-null  object
#  7   auinf_local_km           256611 non-null  object
#  8   auinf_local_referencia   252956 non-null  object
#  9   auinf_local_complemento  25178 non-null   object
#  10  auinf_local_latitude     209724 non-null  object
#  11  auinf_local_longitude    209724 non-null  object
#  12  grav_tipo                815923 non-null  object
# dtypes: object(13)
# memory usage: 80.9+ MB
# None

# %% [markdown]
# ### 3.1 Avaliação de Completude (Nulos)

# %%
nulos = df.isna().sum()
prop = (nulos / len(df) * 100).round(2)
tab_nulos = pd.DataFrame({'qtd_nulos': nulos, 'proporcao_%': prop})
display(tab_nulos[tab_nulos['qtd_nulos'] > 0])
# Out:
#                          qtd_nulos  proporcao_%
# auinf_local_rodovia           1987         0.24
# auinf_local_km              559312        68.55
# auinf_local_referencia      562967        69.00
# auinf_local_complemento     790745        96.91
# auinf_local_latitude        606199        74.30
# auinf_local_longitude       606199        74.30

# %% [markdown]
# ### 3.2 Duplicatas

# %%
n_dup = df.duplicated().sum()
print(f'Linhas totalmente duplicadas: {n_dup}')
print(f'Proporção: {n_dup/len(df)*100:.2f}%')
# Out:
# Linhas totalmente duplicadas: 26970
# Proporção: 3.31%

# %% [markdown]
# ## 4. Análise da Distribuição das Variáveis
#
# Para cada coluna relevante, examinamos a frequência dos valores. Isso permite identificar inconsistências, variações de grafia e categorias que precisam ser padronizadas.

# %%
# Conta os valores unicos de cada coluna categorica para verificar inconsistencias
for column in df.columns[(df.columns != df["auinf_local_km"].name) & (df.columns != df["auinf_local_referencia"].name) & (df.columns != df["auinf_local_complemento"].name) & (df.columns != df["descricao"].name) & (df.columns != df["auinf_local_latitude"].name) & (df.columns != df["auinf_local_longitude"].name)]:
    display(df[column].value_counts())
# Out:
# tipo_infracao
# 7455-0    376268
# 5681-0    176639
# 7463-0     39901
# 5843-3     30666
# 6769-0     23729
#            ...
# 7552-2         1
# 6424-0         1
# 6394-3         1
# 6939-2         1
# 5088-2         1
# Name: count, Length: 249, dtype: int64
# tipo_infrator
# Condutor           765132
# Proprietário        50709
# Emb/Transp             78
# Pessoa Jurídica         2
# Pessoa Física           2
# Name: count, dtype: int64
# tipo_veiculo
# AUTOMOVEL                    286014
# Automóvel                    182298
# CAMINHONETE                   50806
# AUTOMOVEL                     50779
# MOTOCICLETA                   50264
# CAMIONETA                     32109
# Caminhonete                   25359
# UTILITARIO                    22894
# Motocicleta                   18523
# CAMINHAO                      13595
# Camioneta                     13289
# SEMI-REBOQUE                  12107
# CAMINHONET                     7970
# MOTOCICLET                     7593
# Utilitário                     7279
# CAMIONETA                      4648
# Caminhão Trator                4587
# Caminhão                       4021
# UTILITARIO                     3175
# MOTONETA                       2643
# ONIBUS                         2576
# CAMINHAO TRATOR                2356
# S.REBOQUE                      1975
# CAMINHAO                       1878
# MICROONIBUS                    1443
# Motoneta                       1253
# REBOQUE                        1114
# Microônibus                     635
# Ônibus                          537
# Reboque                         483
# C. TRATOR                       319
# MOTONETA                        297
# Semi-Reboque                    278
# ONIBUS                          160
# MICROONIBU                      158
# REBOQUE                         157
# CICLOMOTOR                      115
# Ciclomotor                       54
# MOTOR CASA                       41
# TRICICLO                         28
# Motor-Casa                       27
# TRATOR DE RODAS                  23
# MOTOR-CASA                       19
# Triciclo                         10
# CICLOMOTOR                        9
# TRICICLO                          7
# MOTOR CASA                        6
# Chassi Plataforma                 4
# Tr Misto                          4
# Tr Rodas                          1
# Carro-de-mão                      1
# SIDE CAR                          1
# Charrete                          1
# Name: count, dtype: int64
# cometimento
# 05/09/2025    4288
# 18/07/2025    4250
# 25/07/2025    4183
# 22/12/2025    4172
# 16/07/2025    3863
#               ...
# 27/12/2025     609
# 30/08/2025     391
# 31/12/2025     309
# 28/12/2025     292
# 31/08/2025     146
# Name: count, Length: 365, dtype: int64
# hora_cometimento
# 17:10    1463
# 16:57    1440
# 16:55    1416
# 17:03    1414
# 17:00    1403
#          ...
# 02:17     105
# 03:04     102
# 03:09     101
# 03:36     101
# 03:17     100
# Name: count, Length: 1440, dtype: int64
# auinf_local_rodovia
# DF 001                                                      57677
# DF-075(EPNB) Km 2,5 SENT. N.BAND / RIACHO FUNDO - DER097    45043
# DF 075                                                      35547
# DF-075(EPNB) Km 4,4 SENT. N.BAND / RIACHO FUNDO - DER102    30851
# DF-075(EPNB) Km 3,5 SENT. N.BAND / RIACHO FUNDO - DER099    27385
#                                                             ...
# DF 003 Km 24                                                    1
# DF-025 km 02                                                    1
# Ceilândia                                                       1
# DF-075, KM-06                                                   1
# EPIA DF 003                                                     1
# Name: count, Length: 1743, dtype: int64
# grav_tipo
# Média         417111
# Leve          178088
# Grave         132883
# Gravíssima     87841
# Name: count, dtype: int64

# %% [markdown]
# ---
# ## Processamento e Limpeza de Dados (Documentação)

# %% [markdown]
# ### 1. Padronização de Texto e Valores Nulos
# Garante que não haverá duplicatas por causa de letras maiúsculas ou acentos, e trata informações vazias.

# %%
# Padroniza os textos para minusculo, sem acento
import unicodedata
import re
import numpy as np

def standardize_text(text):
    if pd.isna(text) or str(text).strip() == '' or str(text).lower() == 'nan': return np.nan
    text = str(text).lower().strip()
    text = ''.join(c for c in unicodedata.normalize('NFD', text) if unicodedata.category(c) != 'Mn')
    return re.sub(r'\s+', ' ', text)

text_cols = ['tipo_infracao', 'descricao', 'tipo_infrator', 'tipo_veiculo', 'auinf_local_rodovia', 'auinf_local_referencia', 'auinf_local_complemento', 'grav_tipo']
for col in text_cols:
    if col in df.columns: df[col] = df[col].apply(standardize_text)

# %% [markdown]
# - Termos como 'AUTOMÓVEL' e 'automovel' passaram a ser idênticos ('automovel').

# %% [markdown]
# ### 2. Conversão de Datas e Criação de Features
# Transforma as colunas de data/hora nos seus respectivos formatos nativos e cria a coluna indicando o dia da semana.

# %%
# Converte cometimento para Datetime, hora_cometimento para Timedelta e extrai o dia da semana

if 'cometimento' in df.columns:
    df['cometimento'] = df['cometimento'].replace('Nao informado', np.nan)
    df['cometimento'] = pd.to_datetime(df['cometimento'], format='%d/%m/%Y', errors='coerce')

if 'hora_cometimento' in df.columns:
    def parse_hora(h):
        h = str(h).strip()
        if h.lower() in ['nan', 'nao informado', '', 'nat']: return np.nan
        if len(h) == 5: return h + ':00' # Transforma 14:30 em 14:30:00
        return h
    
    df['hora_cometimento'] = df['hora_cometimento'].apply(parse_hora)
    df['hora_cometimento'] = pd.to_timedelta(df['hora_cometimento'], errors='coerce')

dias_semana = {0: 'segunda-feira', 1: 'terca-feira', 2: 'quarta-feira', 3: 'quinta-feira', 4: 'sexta-feira', 5: 'sabado', 6: 'domingo'}
if 'cometimento' in df.columns:
    df['dia_da_semana'] = df['cometimento'].dt.dayofweek.map(dias_semana).fillna('Nao informado')

# %% [markdown]
# - O `cometimento` passou a ser o tipo `datetime`.
# - A `hora_cometimento` passou a ser o tipo `timedelta`, perfeito para cálculos temporais.
# - Criamos a coluna `dia_da_semana` baseada no calendário real.

# %% [markdown]
# ### 3. Cruzamento de Dados — Valores das Multas
#
# Carregamos a tabela de referência `dados/codigos_valores_multas.csv`, construída a partir dos valores-base do CTB e dos multiplicadores definidos na **Portaria SENATRAN n.º 354/2022** (Anexo N4). O cruzamento é feito pelo código da infração (`tipo_infracao`), gerando a coluna `valor_multa` com o valor em R$ já como `float`.

# %%
import os

# Le a tabela de referencia de multas (codigo -> valor em R$)
df_multas = pd.read_csv(os.path.join('dados', 'codigos_valores_multas.csv'), sep=',')
# Renomeia para facilitar o código padrão independentemente do CSV original
df_multas.columns = ['codigo_infracao', 'valor_multa']

# Padroniza o codigo para bater com tipo_infracao (ja em lowercase sem acento)
df_multas['codigo_infracao'] = df_multas['codigo_infracao'].str.strip().str.lower()

# Remove coluna antiga caso ja exista (evita conflito no merge)
if 'valor_multa' in df.columns:
    df.drop(columns=['valor_multa'], inplace=True)

# Merge left: mantem todas as autuacoes, anexa o valor quando ha correspondencia
df = df.merge(df_multas, left_on='tipo_infracao', right_on='codigo_infracao', how='left')
df.drop(columns=['codigo_infracao'], inplace=True)

# %% [markdown]
# - O cruzamento adicionou a coluna `valor_multa` (tipo `float64`) a cada autuação.
# - Os valores já estão em R$ prontos para uso analítico, sem necessidade de parsing adicional.

# %% [markdown]
# ### 4. Limpeza Final e Feature Engineering

# %%
# Remover duplicatas exatas
df = df.drop_duplicates().reset_index(drop=True)

# Normalizar tipo_veiculo: corrigir truncamentos
mapa_veiculo = {
    'caminhonet': 'caminhonete',
    'motociclet': 'motocicleta',
    'microonibu': 'microonibus',
    's.reboque': 'semi-reboque',
    'c. trator': 'caminhao trator',
    'motor-casa': 'motor casa',
    'tr rodas': 'trator de rodas',
}
df['tipo_veiculo'] = df['tipo_veiculo'].replace(mapa_veiculo)

# hora_cometimento (timedelta) -> hora inteira do dia (0 a 23)
df['hora'] = (df['hora_cometimento'].dt.total_seconds() // 3600).astype('Int64')

# Mês a partir da data
df['mes'] = df['cometimento'].dt.month

# Extrair o código da rodovia (df-001, df-075, br-020 ...) do texto
def extrai_rodovia(texto):
    t = str(texto).lower()
    m = re.search(r'\b(df|br)\s*-?\s*(\d{3})\b', t)
    if m:
        return f'{m.group(1)}-{m.group(2)}'
    m2 = re.match(r'^\s*(\d{3})\b', t)
    if m2:
        return f'df-{m2.group(1)}'
    return 'outra/nao identificada'

df['rodovia'] = df['auinf_local_rodovia'].apply(extrai_rodovia)

# Gravidade como categoria ordenada
ordem_grav = ['leve', 'media', 'grave', 'gravissima']
df['grav_tipo'] = pd.Categorical(df['grav_tipo'], categories=ordem_grav, ordered=True)

# %% [markdown]
# ### 5. Remoção de colunas que não seram usadas para analise

# %%
# Remover tipo_infracao, hora_cometimento e todas as colunas auinf

colunas_para_remover = ['tipo_infracao', 'hora_cometimento']
colunas_auinf = [col for col in df.columns if col.startswith('auinf')]
colunas_para_remover.extend(colunas_auinf)

df = df.drop(columns=colunas_para_remover, errors='ignore')

# %% [markdown]
# ### 4. Exportação para Parquet
#
# Salvamos o DataFrame limpo e enriquecido no formato Parquet, que preserva os tipos nativos (`datetime`, `timedelta`, `float64`) e oferece leitura muito mais rápida do que CSV.

# %%
# Garante que todas as colunas de texto (object) sejam strings puras para evitar erros no PyArrow
for col in df.select_dtypes(include=['object']).columns:
    df[col] = df[col].astype("string")

# Salva o DataFrame final com todas as colunas tipadas corretamente
df.to_parquet(os.path.join('dados', 'dados_2025.parquet'), index=False, engine='pyarrow')

# Verifica o resultado carregando de volta e exibindo tipos e amostra
df_check = pd.read_parquet(os.path.join('dados', 'dados_2025.parquet'))
display(df_check.info())
display(df_check)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 788877 entries, 0 to 788876
# Data columns (total 10 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   descricao      788877 non-null  string
#  1   tipo_infrator  788877 non-null  string
#  2   tipo_veiculo   788877 non-null  string
#  3   cometimento    788877 non-null  datetime64[ns]
#  4   grav_tipo      788877 non-null  category
#  5   dia_da_semana  788877 non-null  string
#  6   valor_multa    788877 non-null  float64
#  7   hora           788877 non-null  Int64
#  8   mes            788877 non-null  int32
#  9   rodovia        788877 non-null  string
# dtypes: Int64(1), category(1), datetime64[ns](1), float64(1), int32(1), string(5)
# memory usage: 52.7 MB
# None
#                                                 descricao tipo_infrator  \
# 0       transitar em velocidade superior a maxima perm...      condutor
# 1       transitar em velocidade superior a maxima perm...      condutor
# 2       transitar em velocidade superior a maxima perm...      condutor
# 3       transitar em velocidade superior a maxima perm...      condutor
# 4       transitar em velocidade superior a maxima perm...      condutor
# ...                                                   ...           ...
# 788872  estacionar ao lado ou sobre canteiro central/d...      condutor
# 788873  estacionar ao lado ou sobre canteiro central/d...      condutor
# 788874           parar na pista de rolamento das rodovias      condutor
# 788875  estacionar ao lado ou sobre canteiro central/d...      condutor
# 788876  estacionar ao lado ou sobre canteiro central/d...      condutor
#
#        tipo_veiculo cometimento grav_tipo dia_da_semana  valor_multa  hora  \
# 0         automovel  2025-01-01     grave  quarta-feira       195.23     0
# 1         automovel  2025-01-01     media  quarta-feira       130.16     0
# 2         automovel  2025-01-01     media  quarta-feira       130.16     0
# 3         automovel  2025-01-01     media  quarta-feira       130.16     0
# 4         automovel  2025-01-01     media  quarta-feira       130.16     0
# ...             ...         ...       ...           ...          ...   ...
# 788872    automovel  2025-12-31     grave  quarta-feira       195.23    23
# 788873    automovel  2025-12-31     grave  quarta-feira       195.23    23
# 788874    automovel  2025-12-31     grave  quarta-feira       195.23    23
# 788875    automovel  2025-12-31     grave  quarta-feira       195.23    23
# 788876    automovel  2025-12-31     grave  quarta-feira       195.23    23
#
#         mes rodovia
# 0         1  df-001
# 1         1  df-459
# 2         1  df-075
# 3         1  df-011
# 4         1  df-003
# ...     ...     ...
# 788872   12  df-004
# 788873   12  df-004
# 788874   12  df-004
# 788875   12  df-004
# 788876   12  df-004
#
# [788877 rows x 10 columns]
